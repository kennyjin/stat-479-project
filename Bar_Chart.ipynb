# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
objects = ('CNN(ResNet-34)', 'CNN(LeNet-5)', 'k-NN', 'Random Forest', 'Logistic Regression', 'Random Guessing')
y_pos = np.arange(len(objects))
accuracy = [59.96,46.79,32.72,27.25,23.96, 0.29]

plt.figure(figsize=(15, 10))  # width:20, height:3
plt.bar(y_pos, accuracy, align='center', alpha=0.5)
plt.xticks(y_pos, objects, fontsize=11)
plt.ylabel('Accuracy (%)', {'fontsize': 15})
plt.title('Prediction Accuracy on the Test Set', {'fontsize': 20})

for i, v in enumerate(accuracy):
    plt.text(y_pos[i] - 0.15, v + 0.7, str(v) + "%", {'fontsize': 12})

plt.show()

# %%
labels = ['PCA-100', 'Autoencoder-100']
men_means = [41.90, 37.01]
women_means = [32.72, 26.13]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=[10, 7])
rects1 = ax.bar(x - width/2, men_means, width, label='Training Accuracy')
rects2 = ax.bar(x + width/2, women_means, width, label='Testing Accuracy')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy (%)', {'fontsize': 15})
ax.set_title('k-NN Accuracy for k=15', {'fontsize': 20})
ax.set_xticks(x)
ax.set_xticklabels(labels, {'fontsize': 15})
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height), fontsize=12,
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
labels = ['PCA-100', 'Autoencoder-100', 'Original Training Set']
train_scores = [26.35, 25.56, 28.65]
test_scores = [18.72, 23.77, 23.96]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=[10, 7])
rects1 = ax.bar(x - width/2, train_scores, width, label='Training Accuracy')
rects2 = ax.bar(x + width/2, test_scores, width, label='Testing Accuracy')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy (%)', {'fontsize': 15})
ax.set_title('Logistic Regression Accuracy', {'fontsize': 20})
ax.set_xticks(x)
ax.set_xticklabels(labels, {'fontsize': 15})
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height), fontsize=12,
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
labels = ['PCA-100', 'Autoencoder-100']
pca_scores = [13.77, 97.13]
ae_scores = [7.24, 27.25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=[10, 7])
rects1 = ax.bar(x - width/2, pca_scores, width, label='Training Accuracy')
rects2 = ax.bar(x + width/2, ae_scores, width, label='Testing Accuracy')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy (%)', {'fontsize': 15})
ax.set_title('Random Forest Accuracy', {'fontsize': 20})
ax.set_xticks(x)
ax.set_xticklabels(labels, {'fontsize': 15})
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height), fontsize=12,
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
labels = ['LeNet-5(60 epochs)', 'ResNet-34(10 epochs)']
train_scores = [49.98, 77.97]
test_scores = [46.79, 59.69]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=[10, 7])
rects1 = ax.bar(x - width/2, train_scores, width, label='Training Accuracy')
rects2 = ax.bar(x + width/2, test_scores, width, label='Testing Accuracy')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy (%)', {'fontsize': 15})
ax.set_title('CNN Accuracy', {'fontsize': 20})
ax.set_xticks(x)
ax.set_xticklabels(labels, {'fontsize': 15})
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height), fontsize=12,
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()
